# %% [markdown]
# <a href="https://colab.research.google.com/github/Keyur08/OIBSIP/blob/main/Task2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Unemployment Analysis Using Python**

# %%
import numpy as np
import pandas as pd
import matplotlib as mlp
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
df=pd.read_csv("Unemployment in India.csv")

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
df.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 763             NaN          NaN        NaN                               NaN
# 764             NaN          NaN        NaN                               NaN
# 765             NaN          NaN        NaN                               NaN
# 766             NaN          NaN        NaN                               NaN
# 767             NaN          NaN        NaN                               NaN
#
# ...

# %%
df.shape
# Out:
# (768, 7)

# %%
#Checking for null
df.isna().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
#dropping null values
df=df.dropna()

# %%
df.shape
# Out:
# (740, 7)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
df.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 749  West Bengal   29-02-2020    Monthly                              7.55
# 750  West Bengal   31-03-2020    Monthly                              6.67
# 751  West Bengal   30-04-2020    Monthly                             15.63
# 752  West Bengal   31-05-2020    Monthly                             15.22
# 753  West Bengal   30-06-2020    Monthly                              9.86
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 749           10871168.0                                     44.09  Urban
# 750           10806105.0                                     43.34  Urban
# 751            9299466.0                                     41.20  Urban
# 752            9240903.0                                     40.67  Urban
# 753            9088931.0                                     37.57  Urban

# %%
#printing state with lowest unemployment
print("state with Lowest unemployment:-",df['Region'].value_counts().idxmin())
# Out:
# state with Lowest unemployment:- Chandigarh

# %%
#visualization

fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
df[:10].plot(kind="bar",color="red",figsize=(20,10),ax=ax0)
ax0.set_title("Top 10 States with Highest Unemployment")
ax0.set_xlabel("State")
ax0.set_ylabel("Number of people unemployed in %")
# Out:
# Text(0, 0.5, 'Number of people unemployed in %')
